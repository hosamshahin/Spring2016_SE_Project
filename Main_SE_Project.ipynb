# %% [markdown]
# <h1>Globals</h1>

# %%
from __future__ import print_function
from datetime import datetime
from git import Repo, Git
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import time
import os.path
import re, string, ntpath, keyword, json, codecs
import threading
import shutil, errno


skip_projects = [ "meteor"]

tag_names = ["2016-06","2016-01","2015-06","2015-01","2014-06","2014-01","2013-06","2013-01",
"2012-06","2012-01","2011-06","2011-01","2010-06","2010-01","2009-06","2009-01",
"2008-06","2008-01","2007-06","2007-01","2006-06","2006-01","2005-06","2005-01",
"2004-06","2004-01","2003-06","2003-01"]

project_type_map = {
	"androidannotations-tags": ".java",
	"bigbluebutton-tags": ".java",
	"cassandra-tags": ".java",
	"elasticsearch-tags": ".java",
	"hibernate-orm-tags": ".java",
	"liferay-portal-tags": ".java",
	"netty-tags": ".java",
	"platform_frameworks_base-tags": ".java",
	"spring-framework-tags": ".java",
	"wildfly-tags": ".java",
	"laravel-tags": ".php",
	"symfony-tags": ".php",
	"cakephp-tags": ".php",
	"CodeIgniter-tags": ".php",
	"rails-tags": ".rb",
	"sinatra-tags": ".rb",
	"padrino-framework-tags": ".rb",
	"hanami-tags": ".rb",
	"pakyow-tags": ".rb",
	"flask-tags": ".py",
	"django-tags": ".py",
	"web2py-tags": ".py",
	"frappe-tags": ".py",
	"ninja-tags": ".java",
	"meteor-tags": "javascript",
	"express-tags": "javascript",
	"sails-tags": "javascript",
	"mean-tags": "javascript",
	"derby-tags": "javascript",
	"nodal-tags": "javascript"
}

def load_config(config_file):
    """
    Load projects configuration file.
    """
    with open(config_file) as data_file:    
        config_data = json.load(data_file)
    return config_data

def copy_folder(src, dst):
    try:
        if os.path.exists(dst):
            shutil.rmtree(dst)
        shutil.copytree(src, dst)
    except OSError as exc: # python >2.5
        if exc.errno == errno.ENOTDIR:
            shutil.copy(src, dst)
        else: raise
            
def get_immediate_subdirectories(a_dir):
    return [name for name in os.listdir(a_dir)
            if os.path.isdir(os.path.join(a_dir, name))]

base_dir = "/home/hshahin/workspaces/Spring2016_SE_Project"
data_dir = os.path.join(base_dir , "data")
config_file = "projects_config.json"
config_data = load_config(os.path.join(base_dir , config_file))

# %%
# path = '/home/hshahin/workspaces/Spring2016_SE_Project/data'
# get_immediate_subdirectories(path)

# %% [markdown]
# <h1>Creating tags functions</h1>

# %%
def get_date_time(epoch):
    '''
    convert epoch to date_time
    '''
    return time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(epoch))

def tag_exists(path, tag_name):
    repo = Repo(path)
    
    return True if tag_name in repo.tags else False

def get_epoch(year, month='01'):
    """
    calculate the epoch of first day of a year-month
    """
    pattern = '%Y.%m.%d %H:%M:%S'
    return int(time.mktime(time.strptime(str(year) + '.' + str(month) + '.01 00:00:00', pattern)))


def create_tags(path):
    '''
    takes repo path and creates tags for first commit in Jan and Jun. for every year
    # get the list of commits
    # get the latest commit date
    # current_year is the year from that date
    # loop through the list of commit to find the commit having a date equal or just after 1/1/current_year
    # once found create a tage with the current_year name on it AND
    # subtract 1 from the year and continue.

    '''
    repo = Repo(path)

    # get the list of commits
    commits = list(repo.iter_commits())

    # get the latest commit date, current_year is the year from that date
    current_year = datetime.fromtimestamp(commits[0].committed_date).year


    for idx, commit in enumerate(commits):
        # time.sleep(2)
        # print(commits[idx].hexsha)

        current_year_01 = str(current_year)+'-01'
        current_year_06 = str(current_year)+'-06'

        try:
            if get_epoch(current_year, '01') > commit.committed_date and \
                    int(time.time()) > get_epoch(current_year, '01')  and \
                    idx !=0:
                if str(current_year_01) not in repo.tags and idx != 0:
                    print(commits[idx-1].hexsha+' '+get_date_time(commits[idx-1].committed_date)+' '+current_year_01)
                    past = repo.create_tag(current_year_01, ref=commits[idx-1],
                                      message="This is a tag to mark the first commit in year %s" % current_year_01)
                current_year = datetime.fromtimestamp(commit.committed_date).year

            if get_epoch(current_year, '06') > commit.committed_date and \
                    int(time.time()) > get_epoch(current_year, '06') and \
                idx != 0:
                if str(current_year_06) not in repo.tags:
                    print(commits[idx-1].hexsha+' '+get_date_time(commits[idx-1].committed_date)+' '+current_year_06)
                    past = repo.create_tag(current_year_06, ref=commits[idx-1],
                                      message="This is a tag to mark the first commit in year %s" % current_year_06)
        except AttributeError:
            pass

def checkout_tag(path, tag_name):
    '''
    checks out a tag if it exists
    '''
    repo = Repo(path)
    git = Git(path)
    if tag_name in repo.tags:
        git.checkout(tag_name)

def delete_tags(path):
    '''
    remove all tags in a given repo
    '''

    repo = Repo(path)

    for tag in repo.tags:
        repo.delete_tag(tag)

# %% [markdown]
# <h1>Create tags every 6 months for each repo</h1>

# %%
# for project_name, project_type in config_data.items():
#     print("Processing project: " + project_name )
#     t0 = time.time()
#     delete_tags(os.path.join(data_dir, project_name))
#     create_tags(os.path.join(data_dir, project_name))
#     print("Project: " + project_name + " taged in %0.3fs." % (time.time() - t0))

# %% [markdown]
# <h1>Preprocesing functions</h1>

# %%
# Python keywords
python_keywords = keyword.kwlist

# Java keywords from https://docs.oracle.com/javase/tutorial/java/nutsandbolts/_keywords.html
java_keywords = ["abstract","continue","for","new","switch","assert","default","goto","package","synchronized",
                 "boolean","do","if","private","this","break","double","implements","protected","throw",
                 "byte","else","import","public","throws","case","enum","instanceof","return","transient","catch",
                 "extends","int","short","try","char","final","interface","static","void","class","finally","long",
                 "strictfp","volatile","const","float","native","super","while"]

# Ruby keywords from http://docs.ruby-lang.org/en/2.2.0/keywords_rdoc.html
ruby_keywords = ["__ENCODING__","__LINE__","__FILE__","BEGIN","END","alias","and","begin","break",
                 "case","class","def","defined?","do","else","elsif","end","ensure","false","for","if",
                 "in","module","next","nil","not","or","redo","rescue","retry","return","self","super",
                 "then","true","undef","unless","until","when","while","yield"]

# PHP keywords form http://php.net/manual/en/reserved.keywords.php
php_keywords = ["__halt_compiler","abstract","and","array","as","break","callable","case","catch","class","clone",
                "const","continue","declare","default","die","do","echo","else","elseif","empty","enddeclare",
                "endfor","endforeach","endif","endswitch","endwhile","eval","exit","extends","final","finally",
                "for","foreach","function","global","goto","if","implements","include","include_once","instanceof",
                "insteadof","interface","isset","list","namespace","new","or","print","private","protected",
                "public","require","require_once","return","static","switch","throw","trait","try","unset","use",
                "var","while","xor","yield"]

all_keywords = python_keywords + java_keywords + ruby_keywords + php_keywords


def path_leaf(path):
    head, tail = ntpath.split(path)
    return head, tail

# split camel case tokens
_underscorer1 = re.compile(r'(.)([A-Z][a-z]+)')
_underscorer2 = re.compile('([a-z0-9])([A-Z])')


def camel_to_spaces(s):
    """
    convert camel case into spaces seperated
    """
    subbed = _underscorer1.sub(r'\1 \2', s)
    return _underscorer2.sub(r'\1 \2', subbed).lower()

def snake_to_spaces(snake_cased_str):
    """
    convert snake case into spaces seperated
    """
    separator = "_"
    components = snake_cased_str.split(separator)
    if components[0] == "":
        components = components[1:]
    if components[-1] == "":
        components = components[:-1]
    if len(components) > 1:
        spaced_str = components[0].lower()
        for x in components[1:]:
            spaced_str += " " + x.lower()
    else:
        spaced_str = components[0]
    return spaced_str


def file_preprocessing(input_file, output_file):
    """
    - replace punctuations with spaces
    - stemming
    - camel to spaces and snake to spaces
    - remove language spesific keywords
    - write the entire project snapshot into one file under project root folder
    """
    # print("processing file " + input_file)
    # replace the punctuations with space
    replace_punctuation = str.maketrans(string.punctuation, ' '*len(string.punctuation))
    # stemming
    stemmer = PorterStemmer()

    with open(input_file, 'r', encoding='utf-8', errors='replace') as inFile, open(output_file,'w') as outFile:
        for line in inFile:
            # replace punctuations
            # convert camel case into space separated
            # convert snake case into space separated             
            # remove language keywords
            line_witout_puncs = ' '.join([snake_to_spaces(camel_to_spaces(word)) 
                                          for word in line.translate(replace_punctuation).split()
                                          if len(word) >=4 and word not in stopwords.words('english') 
                                          and word not in all_keywords])

            # stemming
            singles = []
            for plural in line_witout_puncs.split():
                try:
                    singles.append(stemmer.stem(plural))
                except UnicodeDecodeError:
                    print(plural) 

            line_stemmed = ' '.join(singles)
            print(line_stemmed, file=outFile)


def return_file_type(project_path, file_type):
    project_files = [os.path.join(root, name)
             for root, dirs, files in os.walk(project_path)
             for name in files
             if name.endswith((file_type))]
    return project_files

def project_preprocessing(project_path, file_type, tag_name):
    # print ("processing project "+ project_path)
    # process project source code files and save each file as .*.proc 
    project_files = return_file_type (project_path, file_type)
    for source_file in project_files:
        head, tail = path_leaf(source_file)
        proc_file = os.path.join(head , tail + '.proc')
        file_preprocessing(source_file, proc_file)
        
    # concatenate all processed project files into one file under root directory
    project_proc_files = return_file_type (project_path, file_type + '.proc')
    with open(os.path.join(project_path , "final-processed.out"), 'w') as outfile:
        for fname in project_proc_files:
            with open(fname) as infile:
                for line in infile:
                    outfile.write(line)

# %% [markdown]
# <h1>checkout tags in separate folders</h1>

# %%
# create folder project_tags
# for each tag if tag exists
# copy the project into project_tag/tag_name
# checkout ptoject to tag_name
# delete .git folder
# def checkout_projects():
#     for project_name, project_type in config_data.items():
#         project_path = os.path.join(data_dir, project_name)
#         project_tags_path = project_path + '-tags'
        
#         if project_name not in skip_projects:
#             if not os.path.exists(project_tags_path):
#                 os.makedirs(project_tags_path)

#             repo = Repo(project_path)
#             for tag_name in tag_names:
#                 if tag_exists(project_path, tag_name):
#                     print("Copying "+project_name+' '+tag_name)
#                     current_tag_path = os.path.join(project_tags_path, tag_name)
#                     copy_folder(project_path, current_tag_path)

#             for tag_name in tag_names:
#                 if tag_exists(project_path, tag_name):
#                     print("Checkout "+project_name+' '+tag_name)
#                     current_tag_path = os.path.join(project_tags_path, tag_name)
#                     checkout_tag(current_tag_path, tag_name)

#             for tag_name in tag_names:
#                 if tag_exists(project_path, tag_name):
#                     print("deleting .git "+project_name+' '+tag_name)
#                     current_tag_path = os.path.join(project_tags_path, tag_name)
#                     os.chdir(current_tag_path)
#                     shutil.rmtree(os.path.join(current_tag_path, '.git'))

# checkout_projects()

# %% [markdown]
# <h1>Run preprocessing</h1>

# %%
from multiprocessing import Pool

def run_preprocessing(project_tags_dir):
    project_tags_path = os.path.join(data_dir , project_tags_dir)
    print('---------------'+project_tags_path)

    for project_tag in get_immediate_subdirectories(project_tags_path):
        project_tag_path = os.path.join(project_tags_path , project_tag)
        t0 = time.time()
        project_preprocessing(project_tag_path, project_type_map[project_tags_dir], project_tag)
        print("processing project: " + project_tags_path + "\t tag " 
              + project_tag + " done in %0.3fs." % (time.time() - t0))
    print('****This thread is done:', os.getpid())
     

project_tags_paths = get_immediate_subdirectories(data_dir)
pool = Pool(16)
pool.map(run_preprocessing, project_tags_paths)
   
# for project_tags_path in get_immediate_subdirectories(data_dir):
#     preprocessing_threads = threading.Thread(target=run_preprocessing, args=(project_tags_path, ))
#     preprocessing_threads.start()
    
print('Main process Done...............')
# Out:
# ---------------/home/hshahin/workspaces/Spring2016_SE_Project/data/sinatra-tags
# ---------------/home/hshahin/workspaces/Spring2016_SE_Project/data/web2py-tags
# ---------------/home/hshahin/workspaces/Spring2016_SE_Project/data/symfony-tags
# ---------------/home/hshahin/workspaces/Spring2016_SE_Project/data/netty-tags
# ---------------/home/hshahin/workspaces/Spring2016_SE_Project/data/mean-tags
# ---------------/home/hshahin/workspaces/Spring2016_SE_Project/data/androidannotations-tags
# ---------------/home/hshahin/workspaces/Spring2016_SE_Project/data/sails-tags
# ---------------/home/hshahin/workspaces/Spring2016_SE_Project/data/laravel-tags
# ---------------/home/hshahin/workspaces/Spring2016_SE_Project/data/pakyow-tags
# ---------------/home/hshahin/workspaces/Spring2016_SE_Project/data/bigbluebutton-tags
# ---------------/home/hshahin/workspaces/Spring2016_SE_Project/data/django-tags
# ---------------/home/hshahin/workspaces/Spring2016_SE_Project/data/frappe-tags
# ---------------/home/hshahin/workspaces/Spring2016_SE_Project/data/derby-tags
# ---------------/home/hshahin/workspaces/Spring2016_SE_Project/data/wildfly-tags
# ---------------/home/hshahin/workspaces/Spring2016_SE_Project/data/meteor-tags
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/mean-tags	 tag 2014-06 done in 0.009s.
# ---------------/home/hshahin/workspaces/Spring2016_SE_Project/data/hanami-tags
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/derby-tags	 tag 2014-06 done in 0.003s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/sails-tags	 tag 2014-06 done in 0.010s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/sails-tags	 tag 2016-01 done in 0.007s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/derby-tags	 tag 2012-01 done in 0.004s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/mean-tags	 tag 2016-01 done in 0.016s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/sails-tags	 tag 2013-06 done in 0.005s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/derby-tags	 tag 2016-01 done in 0.002s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/mean-tags	 tag 2013-06 done in 0.003s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/derby-tags	 tag 2013-06 done in 0.004s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/sails-tags	 tag 2014-01 done in 0.008s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/mean-tags	 tag 2014-01 done in 0.004s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/derby-tags	 tag 2014-01 done in 0.003s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/sails-tags	 tag 2012-06 done in 0.003s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/derby-tags	 tag 2011-06 done in 0.001s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/derby-tags	 tag 2012-06 done in 0.002s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/sails-tags	 tag 2015-01 done in 0.005s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/derby-tags	 tag 2015-01 done in 0.001s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/mean-tags	 tag 2015-01 done in 0.006s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/derby-tags	 tag 2015-06 done in 0.001s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/meteor-tags	 tag 2016-01 done in 0.061s.
# ****This thread is done: 27455
# ---------------/home/hshahin/workspaces/Spring2016_SE_Project/data/elasticsearch-tags
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/mean-tags	 tag 2015-06 done in 0.008s.
# ****This thread is done: 27440
# ---------------/home/hshahin/workspaces/Spring2016_SE_Project/data/flask-tags
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/sails-tags	 tag 2015-06 done in 0.013s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/sails-tags	 tag 2013-01 done in 0.001s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/derby-tags	 tag 2013-01 done in 0.002s.
# ****This thread is done: 27445
# ---------------/home/hshahin/workspaces/Spring2016_SE_Project/data/rails-tags
# ****This thread is done: 27447
# ---------------/home/hshahin/workspaces/Spring2016_SE_Project/data/CodeIgniter-tags
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/hanami-tags	 tag 2014-06 done in 0.325s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/laravel-tags	 tag 2014-06 done in 0.738s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/pakyow-tags	 tag 2014-06 done in 3.139s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/sinatra-tags	 tag 2014-06 done in 4.447s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/pakyow-tags	 tag 2012-01 done in 1.987s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/laravel-tags	 tag 2012-01 done in 5.079s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/laravel-tags	 tag 2016-01 done in 0.782s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/flask-tags	 tag 2014-06 done in 7.080s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/laravel-tags	 tag 2013-06 done in 0.677s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/laravel-tags	 tag 2014-01 done in 0.687s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/sinatra-tags	 tag 2012-01 done in 3.551s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/hanami-tags	 tag 2016-01 done in 8.192s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/hanami-tags	 tag 2014-01 done in 0.197s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/pakyow-tags	 tag 2016-01 done in 6.487s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/hanami-tags	 tag 2015-01 done in 3.056s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/flask-tags	 tag 2012-01 done in 4.999s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/sinatra-tags	 tag 2016-01 done in 4.587s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/frappe-tags	 tag 2014-06 done in 12.746s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/pakyow-tags	 tag 2013-06 done in 2.186s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/hanami-tags	 tag 2015-06 done in 4.534s.
# ****This thread is done: 27454
# ---------------/home/hshahin/workspaces/Spring2016_SE_Project/data/ninja-tags
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/pakyow-tags	 tag 2014-01 done in 2.643s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/sinatra-tags	 tag 2013-06 done in 4.324s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/pakyow-tags	 tag 2012-06 done in 2.190s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/flask-tags	 tag 2016-01 done in 7.014s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/frappe-tags	 tag 2012-01 done in 6.899s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/sinatra-tags	 tag 2014-01 done in 4.349s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/pakyow-tags	 tag 2015-01 done in 3.601s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/androidannotations-tags	 tag 2014-06 done in 22.319s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/sinatra-tags	 tag 2010-06 done in 2.278s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/laravel-tags	 tag 2012-06 done in 15.723s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/laravel-tags	 tag 2015-01 done in 0.724s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/laravel-tags	 tag 2015-06 done in 0.745s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/flask-tags	 tag 2013-06 done in 6.334s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/sinatra-tags	 tag 2009-06 done in 2.004s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/CodeIgniter-tags	 tag 2014-06 done in 26.411s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/sinatra-tags	 tag 2009-01 done in 1.428s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/pakyow-tags	 tag 2015-06 done in 4.773s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/pakyow-tags	 tag 2013-01 done in 2.287s.
# ****This thread is done: 27449
# ---------------/home/hshahin/workspaces/Spring2016_SE_Project/data/cakephp-tags
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/sinatra-tags	 tag 2011-06 done in 3.124s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/ninja-tags	 tag 2014-06 done in 15.047s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/flask-tags	 tag 2014-01 done in 6.554s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/androidannotations-tags	 tag 2012-01 done in 9.842s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/flask-tags	 tag 2010-06 done in 1.687s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/sinatra-tags	 tag 2012-06 done in 3.808s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/sinatra-tags	 tag 2008-01 done in 0.309s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/sinatra-tags	 tag 2008-06 done in 1.185s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/flask-tags	 tag 2011-06 done in 2.840s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/sinatra-tags	 tag 2015-01 done in 4.527s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/frappe-tags	 tag 2016-01 done in 21.503s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/flask-tags	 tag 2012-06 done in 5.645s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/sinatra-tags	 tag 2015-06 done in 4.423s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/CodeIgniter-tags	 tag 2012-01 done in 17.992s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/laravel-tags	 tag 2013-01 done in 20.511s.
# ****This thread is done: 27448
# ---------------/home/hshahin/workspaces/Spring2016_SE_Project/data/nodal-tags
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/nodal-tags	 tag 2016-01 done in 0.002s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/nodal-tags	 tag 2015-06 done in 0.002s.
# ****This thread is done: 27448
# ---------------/home/hshahin/workspaces/Spring2016_SE_Project/data/express-tags
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/express-tags	 tag 2014-06 done in 0.005s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/express-tags	 tag 2012-01 done in 0.005s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/express-tags	 tag 2016-01 done in 0.005s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/express-tags	 tag 2013-06 done in 0.005s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/express-tags	 tag 2014-01 done in 0.005s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/express-tags	 tag 2010-06 done in 0.003s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/express-tags	 tag 2011-06 done in 0.005s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/express-tags	 tag 2012-06 done in 0.005s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/express-tags	 tag 2015-01 done in 0.005s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/express-tags	 tag 2015-06 done in 0.005s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/express-tags	 tag 2010-01 done in 0.003s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/express-tags	 tag 2011-01 done in 0.007s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/express-tags	 tag 2013-01 done in 0.007s.
# ****This thread is done: 27448
# ---------------/home/hshahin/workspaces/Spring2016_SE_Project/data/cassandra-tags
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/sinatra-tags	 tag 2010-01 done in 2.088s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/flask-tags	 tag 2015-01 done in 6.671s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/sinatra-tags	 tag 2011-01 done in 2.618s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/frappe-tags	 tag 2013-06 done in 9.754s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/sinatra-tags	 tag 2013-01 done in 3.932s.
# ****This thread is done: 27441
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/bigbluebutton-tags	 tag 2014-06 done in 54.847s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/ninja-tags	 tag 2016-01 done in 23.725s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/flask-tags	 tag 2015-06 done in 6.961s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/flask-tags	 tag 2011-01 done in 2.715s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/frappe-tags	 tag 2014-01 done in 10.056s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/flask-tags	 tag 2013-01 done in 6.211s.
# ****This thread is done: 27440
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/ninja-tags	 tag 2013-06 done in 10.269s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/androidannotations-tags	 tag 2016-01 done in 33.418s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/frappe-tags	 tag 2012-06 done in 7.616s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/CodeIgniter-tags	 tag 2016-01 done in 28.611s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/ninja-tags	 tag 2014-01 done in 12.656s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/netty-tags	 tag 2014-06 done in 82.239s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/frappe-tags	 tag 2015-01 done in 16.436s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/androidannotations-tags	 tag 2013-06 done in 19.507s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/web2py-tags	 tag 2014-06 done in 92.276s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/ninja-tags	 tag 2015-01 done in 18.793s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/bigbluebutton-tags	 tag 2012-01 done in 42.844s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/CodeIgniter-tags	 tag 2013-06 done in 24.731s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/frappe-tags	 tag 2015-06 done in 18.194s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/androidannotations-tags	 tag 2014-01 done in 20.921s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/androidannotations-tags	 tag 2011-06 done in 5.683s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/frappe-tags	 tag 2013-01 done in 8.536s.
# ****This thread is done: 27452
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/symfony-tags	 tag 2014-06 done in 113.624s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/ninja-tags	 tag 2015-06 done in 20.559s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/CodeIgniter-tags	 tag 2014-01 done in 25.141s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/androidannotations-tags	 tag 2012-06 done in 13.751s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/ninja-tags	 tag 2013-01 done in 8.185s.
# ****This thread is done: 27454
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/netty-tags	 tag 2012-01 done in 52.786s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/rails-tags	 tag 2014-06 done in 135.070s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/CodeIgniter-tags	 tag 2010-06 done in 14.346s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/web2py-tags	 tag 2012-01 done in 51.723s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/django-tags	 tag 2014-06 done in 144.876s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/cakephp-tags	 tag 2014-06 done in 120.026s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/androidannotations-tags	 tag 2015-01 done in 24.799s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/CodeIgniter-tags	 tag 2009-06 done in 13.679s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/bigbluebutton-tags	 tag 2016-01 done in 60.945s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/CodeIgniter-tags	 tag 2009-01 done in 13.240s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/androidannotations-tags	 tag 2015-06 done in 27.245s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/androidannotations-tags	 tag 2011-01 done in 0.726s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/CodeIgniter-tags	 tag 2011-06 done in 15.200s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/symfony-tags	 tag 2012-01 done in 67.885s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/cassandra-tags	 tag 2014-06 done in 141.204s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/androidannotations-tags	 tag 2013-01 done in 16.958s.
# ****This thread is done: 27446
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/CodeIgniter-tags	 tag 2012-06 done in 20.418s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/bigbluebutton-tags	 tag 2013-06 done in 50.195s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/CodeIgniter-tags	 tag 2008-01 done in 10.205s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/CodeIgniter-tags	 tag 2007-06 done in 9.787s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/web2py-tags	 tag 2016-01 done in 87.163s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/CodeIgniter-tags	 tag 2008-06 done in 12.418s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/cakephp-tags	 tag 2012-01 done in 96.842s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/rails-tags	 tag 2012-01 done in 112.758s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/cakephp-tags	 tag 2006-06 done in 11.494s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/bigbluebutton-tags	 tag 2014-01 done in 50.847s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/CodeIgniter-tags	 tag 2015-01 done in 28.686s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/django-tags	 tag 2012-01 done in 121.620s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/cassandra-tags	 tag 2012-01 done in 83.144s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/netty-tags	 tag 2016-01 done in 143.127s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/django-tags	 tag 2006-06 done in 18.431s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/CodeIgniter-tags	 tag 2015-06 done in 28.598s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/bigbluebutton-tags	 tag 2010-06 done in 33.903s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/rails-tags	 tag 2006-06 done in 46.715s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/symfony-tags	 tag 2016-01 done in 116.353s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/CodeIgniter-tags	 tag 2007-01 done in 9.720s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/elasticsearch-tags	 tag 2014-06 done in 312.105s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/CodeIgniter-tags	 tag 2010-01 done in 13.655s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/web2py-tags	 tag 2013-06 done in 86.924s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/CodeIgniter-tags	 tag 2011-01 done in 14.328s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/netty-tags	 tag 2013-06 done in 68.916s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/CodeIgniter-tags	 tag 2013-01 done in 24.580s.
# ****This thread is done: 27447
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/cakephp-tags	 tag 2016-01 done in 98.353s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/bigbluebutton-tags	 tag 2009-06 done in 74.288s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/symfony-tags	 tag 2013-06 done in 92.369s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/web2py-tags	 tag 2014-01 done in 87.846s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/netty-tags	 tag 2014-01 done in 70.997s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/bigbluebutton-tags	 tag 2009-01 done in 76.547s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/rails-tags	 tag 2016-01 done in 160.508s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/netty-tags	 tag 2010-06 done in 38.743s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/web2py-tags	 tag 2012-06 done in 56.620s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/django-tags	 tag 2016-01 done in 183.572s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/cakephp-tags	 tag 2013-06 done in 112.800s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/cakephp-tags	 tag 2005-06 done in 3.415s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/elasticsearch-tags	 tag 2012-01 done in 164.608s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/bigbluebutton-tags	 tag 2011-06 done in 43.105s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/netty-tags	 tag 2009-06 done in 31.907s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/cassandra-tags	 tag 2016-01 done in 224.361s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/symfony-tags	 tag 2014-01 done in 110.971s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/netty-tags	 tag 2009-01 done in 22.672s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/symfony-tags	 tag 2010-06 done in 20.038s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/bigbluebutton-tags	 tag 2012-06 done in 42.634s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/bigbluebutton-tags	 tag 2008-06 done in 0.102s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/web2py-tags	 tag 2015-01 done in 93.626s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/netty-tags	 tag 2011-06 done in 47.774s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/cakephp-tags	 tag 2014-01 done in 90.402s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/rails-tags	 tag 2013-06 done in 125.738s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/bigbluebutton-tags	 tag 2015-01 done in 54.826s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/symfony-tags	 tag 2011-06 done in 65.286s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/django-tags	 tag 2013-06 done in 127.812s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/netty-tags	 tag 2012-06 done in 45.006s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/cassandra-tags	 tag 2013-06 done in 113.794s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/rails-tags	 tag 2005-06 done in 28.381s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/web2py-tags	 tag 2015-06 done in 86.613s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/bigbluebutton-tags	 tag 2015-06 done in 60.422s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/cakephp-tags	 tag 2010-06 done in 86.198s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/wildfly-tags	 tag 2014-06 done in 656.535s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/symfony-tags	 tag 2012-06 done in 84.686s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/bigbluebutton-tags	 tag 2010-01 done in 57.508s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/web2py-tags	 tag 2013-01 done in 65.249s.
# ****This thread is done: 27443
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/netty-tags	 tag 2015-01 done in 108.146s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/cakephp-tags	 tag 2009-06 done in 76.218s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/cassandra-tags	 tag 2014-01 done in 119.109s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/django-tags	 tag 2014-01 done in 139.678s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/rails-tags	 tag 2014-01 done in 128.535s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/bigbluebutton-tags	 tag 2011-01 done in 42.815s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/cassandra-tags	 tag 2010-06 done in 41.481s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/symfony-tags	 tag 2015-01 done in 115.266s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/bigbluebutton-tags	 tag 2013-01 done in 48.146s.
# ****This thread is done: 27450
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/cakephp-tags	 tag 2009-01 done in 74.002s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/cassandra-tags	 tag 2009-06 done in 31.099s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/django-tags	 tag 2010-06 done in 87.198s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/rails-tags	 tag 2010-06 done in 93.675s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/netty-tags	 tag 2015-06 done in 130.008s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/cassandra-tags	 tag 2011-06 done in 72.667s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/netty-tags	 tag 2010-01 done in 37.352s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/cakephp-tags	 tag 2011-06 done in 92.536s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/django-tags	 tag 2009-06 done in 72.662s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/elasticsearch-tags	 tag 2016-01 done in 424.178s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/netty-tags	 tag 2011-01 done in 43.919s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/rails-tags	 tag 2009-06 done in 101.733s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/symfony-tags	 tag 2015-06 done in 149.247s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/django-tags	 tag 2009-01 done in 62.821s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/cassandra-tags	 tag 2012-06 done in 91.009s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/netty-tags	 tag 2013-01 done in 54.063s.
# ****This thread is done: 27442
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/symfony-tags	 tag 2011-01 done in 42.013s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/cakephp-tags	 tag 2012-06 done in 102.686s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/rails-tags	 tag 2009-01 done in 91.383s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/cakephp-tags	 tag 2008-01 done in 44.431s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/wildfly-tags	 tag 2012-01 done in 391.965s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/cakephp-tags	 tag 2007-06 done in 26.338s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/django-tags	 tag 2011-06 done in 108.320s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/symfony-tags	 tag 2013-01 done in 91.135s.
# ****This thread is done: 27444
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/cakephp-tags	 tag 2006-01 done in 6.702s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/elasticsearch-tags	 tag 2013-06 done in 222.802s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/cassandra-tags	 tag 2015-01 done in 166.352s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/rails-tags	 tag 2011-06 done in 106.390s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/cakephp-tags	 tag 2008-06 done in 61.864s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/django-tags	 tag 2012-06 done in 122.083s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/cakephp-tags	 tag 2015-01 done in 88.632s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/django-tags	 tag 2008-01 done in 40.050s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/rails-tags	 tag 2012-06 done in 115.479s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/django-tags	 tag 2007-06 done in 32.727s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/django-tags	 tag 2006-01 done in 15.270s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/rails-tags	 tag 2008-01 done in 64.257s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/cakephp-tags	 tag 2015-06 done in 91.354s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/django-tags	 tag 2008-06 done in 43.373s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/cassandra-tags	 tag 2015-06 done in 191.858s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/cakephp-tags	 tag 2007-01 done in 15.226s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/cassandra-tags	 tag 2010-01 done in 29.216s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/rails-tags	 tag 2007-06 done in 62.111s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/cassandra-tags	 tag 2011-01 done in 55.381s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/elasticsearch-tags	 tag 2014-01 done in 288.791s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/cakephp-tags	 tag 2010-01 done in 84.026s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/rails-tags	 tag 2006-01 done in 40.475s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/django-tags	 tag 2015-01 done in 158.632s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/wildfly-tags	 tag 2016-01 done in 437.135s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/rails-tags	 tag 2008-06 done in 81.851s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/cakephp-tags	 tag 2011-01 done in 90.003s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/rails-tags	 tag 2005-01 done in 15.515s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/cassandra-tags	 tag 2013-01 done in 111.684s.
# ****This thread is done: 27448
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/elasticsearch-tags	 tag 2010-06 done in 143.480s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/cakephp-tags	 tag 2013-01 done in 98.495s.
# ****This thread is done: 27449
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/django-tags	 tag 2015-06 done in 166.871s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/rails-tags	 tag 2015-01 done in 139.762s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/django-tags	 tag 2007-01 done in 24.302s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/elasticsearch-tags	 tag 2011-06 done in 147.682s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/django-tags	 tag 2010-01 done in 81.333s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/rails-tags	 tag 2015-06 done in 144.341s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/rails-tags	 tag 2007-01 done in 58.200s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/django-tags	 tag 2011-01 done in 101.901s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/elasticsearch-tags	 tag 2012-06 done in 170.493s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/rails-tags	 tag 2010-01 done in 100.331s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/django-tags	 tag 2013-01 done in 120.892s.
# ****This thread is done: 27451
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/wildfly-tags	 tag 2013-06 done in 555.936s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/rails-tags	 tag 2011-01 done in 100.986s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/rails-tags	 tag 2013-01 done in 120.846s.
# ****This thread is done: 27445
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/elasticsearch-tags	 tag 2015-01 done in 351.318s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/elasticsearch-tags	 tag 2015-06 done in 1.797s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/elasticsearch-tags	 tag 2011-01 done in 124.766s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/elasticsearch-tags	 tag 2013-01 done in 194.687s.
# ****This thread is done: 27455
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/wildfly-tags	 tag 2014-01 done in 620.193s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/wildfly-tags	 tag 2010-06 done in 0.881s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/wildfly-tags	 tag 2011-06 done in 160.467s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/wildfly-tags	 tag 2012-06 done in 476.587s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/wildfly-tags	 tag 2015-01 done in 391.527s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/wildfly-tags	 tag 2015-06 done in 394.456s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/wildfly-tags	 tag 2011-01 done in 75.903s.
# processing project: /home/hshahin/workspaces/Spring2016_SE_Project/data/wildfly-tags	 tag 2013-01 done in 533.216s.
# ****This thread is done: 27453
# Main process Done...............

# %% [markdown]
# <h1>Topic Modeling</h1>

# %%
from __future__ import print_function
import os
from time import time
from os import listdir
from os.path import isdir

from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import NMF, LatentDirichletAllocation
from sklearn.datasets import fetch_20newsgroups
import pandas as pd
import numpy as np
# pd.set_option('display.mpl_style', 'default') 
pd.set_option('display.width', 5000) 
pd.set_option('display.max_columns', 60) 
import matplotlib.pyplot as plt

n_features = 1000000
n_topics = 10
# n_top_words = 100


config_file = "projects_config_webFrameworks.json"
# config_file = 'projects_config_topGithub.json'
selected_projects = load_config(os.path.join(base_dir , config_file))


def print_top_words(model, feature_names, n_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print("Topic #%d:" % topic_idx)
        print(" ".join([feature_names[i] for i in topic.argsort()[:-n_top_words - 1:-1]]))
    print()

def get_top_words(model, feature_names, n_top_words):
    df = pd.DataFrame(columns=['word'+str(i) for i in range(n_top_words)])
    for topic_idx, topic in enumerate(model.components_):
        df.loc['topic#'+str(topic_idx)] = [feature_names[i] for i in topic.argsort()[:-n_top_words - 1:-1]]
        df.loc['freq#'+str(topic_idx)] = [topic[i] for i in topic.argsort()[:-n_top_words - 1:-1]]
    
    return df

def get_top_doc_topic(projects_topics, project_names, n_top_words):
    df = pd.DataFrame(columns=['word'+str(i) for i in range(n_top_words)])
    for topic_idx, topic in enumerate(model.components_):
        df.loc['topic#'+str(topic_idx)] = [feature_names[i] for i in topic.argsort()[:-n_top_words - 1:-1]]
        df.loc['freq#'+str(topic_idx)] = [topic[i] for i in topic.argsort()[:-n_top_words - 1:-1]]
    
    return df

def print_full(x):
    pd.set_option('display.max_colwidth', 1000)
    print(x)
    pd.reset_option('display.max_rows')

# Read projects into strings
projects_data = []
project_names = []
for i, project_name in enumerate(selected_projects.keys()):
    # For each snapshot of the project
    snapshots = []
    project_path = os.path.join(data_dir, project_name+'-tags')
    try:
        snapshots = [os.path.join(project_path, p) 
                     for p in listdir(project_path) if isdir(os.path.join(project_path, p))]
    except FileNotFoundError:
         print('------Project Not found: '+project_name)   
    for snapshot in snapshots:
        project_names.append('_'.join(snapshot.split('/')[-2:]))
        # print(project_names[-1])
        processed_path = os.path.join(snapshot, "final-processed.out")
        with open(processed_path, 'r') as myfile:
            projects_data.append(myfile.read().replace('\n', ' '))
            

print('num of projects: ', len(projects_data))
# print(projects_data[0])
   
# Use tf (raw term count) features for LDA.
print("Extracting tf features for LDA...")
tf_vectorizer = CountVectorizer(max_df=0.7, min_df=0.1, max_features=n_features, stop_words='english')

t0 = time()
tf = tf_vectorizer.fit_transform(projects_data)
print("done in %0.3fs." % (time() - t0))

print('tf shape:', tf.shape)

print("Fitting LDA models with tf features")
lda = LatentDirichletAllocation(n_topics=n_topics, max_iter=100,
                                learning_method='online', learning_offset=10.,
                                random_state=0, n_jobs=10)
t0 = time()
lda.fit(tf)

print("done in %0.3fs." % (time() - t0))

# Save lda into a pickle file.
import pickle

pickle.dump(lda, open("lda_7_1.p", "wb"))

# lda = pickle.load(open("lda_5_1.p", "rb"))
# Out:
# ------Project Not found: spring-framework
# ------Project Not found: padrino-framework
# num of projects:  226
# Extracting tf features for LDA...
# done in 108.308s.
# tf shape: (226, 7870)
# Fitting LDA models with tf features
# done in 210.133s.

# %% [markdown]
# ## 1- Topic-word

# %%
print("\nTopics-words in LDA model:")
tf_feature_names = tf_vectorizer.get_feature_names()
topic_word = get_top_words(lda, tf_feature_names, 50)
topic_word.to_csv('topic_word_7_1.csv')
topic_word
# Out:
# Topics-words in LDA model:
#            word0     word1    word2      word3     word4        word5     word6      word7       word8      word9     word10    word11     word12    word13   word14    word15       word16    word17    word18     word19       word20   word21   word22   word23    word24    word25     word26       word27       word28    word29    word30    word31    word32     word33     word34    word35     word36   word37   word38   word39    word40      word41      word42       word43       word44    word45       word46   word47      word48     word49
# topic#0     cake    licens   articl     plugin      true          php   foundat    softwar        fals     associ     fixtur      task   properti  translat     mock     shell         auth    router      rule       book         2007   plural   column    pagin     notic    retain  opensourc  redistribut           ha   primari  dispatch   publish    socket   behavior    project    record        reg   belong  contact    rapid       exp     network       token     categori      foreign    driver         bool     list   inflector       bake
# freq#0   87115.4   41884.7  26243.7      25702   20782.6      18853.3     11462    11261.1     10503.8    10215.2    9763.47   9527.94    9464.23   9377.08  8905.67   7928.39      7900.23   7682.08    7451.2    7297.73      6697.65  6622.24   6330.1  6252.74      6212   5696.76    5673.41      5671.37      5661.48   5540.88   5526.04   5042.62   4930.03    4846.23    4768.88   4645.18    4358.66  4241.84  4216.57  4155.99   4057.58     4044.81     4025.08      3976.51      3965.23   3837.52      3825.32  3773.64        3771    3440.39
# topic#1   record    column    topic    transit    associ       person      rail       firm        zone     migrat     fixtur     david    account     nodoc  project   reflect      respond      2005     klass      month         rubi  compani  destroy    peopl     adapt  dispatch   transact       belong      primari  autoload    mailer  categori     asset    written       proc     child      admin     node   offset    repli  accessor     datetim        task       member      foreign    plugin         word     hour       token      flash
# freq#1   92550.4   51966.2    46489    41862.7   38538.1      37551.2   32712.3    29414.9     22138.4    21047.5    21013.3   20792.6    19637.7   19362.2  18905.3   18381.7      16673.1   15915.8   15559.5    14844.7      14712.7  14561.9  14438.2  14262.2   14058.9   13116.8    11928.3      11472.7      11344.1   11134.2   11133.8   10957.4   10218.1    10197.8    10082.7   9388.78    9345.56  9012.84  8949.46  8923.39   8582.72     8388.03      8032.3      7767.89      7688.05   7564.36       7003.8  6870.37     6785.96    6764.71
# topic#2  symfoni  interfac   licens       node     token     properti     bundl      choic  constraint     street  distribut    servic  transform    kernel  factori    listen       resolv      mock  metadata    formatt      sprintf     true       id    child    fixtur  translat   dispatch          php        ident    profil    storag        ha  children       fals       twig    violat    foundat     intl     role      dir       bag     doctrin       gmail       finder  constructor       acl      matcher     tran        list       bool
# freq#2    197211   70192.3  58530.2    42771.6   39556.4      39407.1   32778.1    30116.1     28373.8    28267.8    28213.9   27869.5    26354.7   25026.2  23677.6   20380.7        18221   18060.1   17254.6    16573.3      15823.7  14250.3  14195.6  13995.8   13593.4   13336.7      13263      12122.1      11733.9   11676.5   11629.5   11490.8   11275.6    10629.9    10467.9   10190.8    9802.68  9719.87  9549.48  9001.87   8717.47     8603.37     8384.83      8264.37      8138.44   8069.96      8033.49   7859.2     7790.38    7628.02
# topic#3   django     admin  datetim     articl     kwarg         dict     choic     unicod        book  middlewar     python   contrib     lookup       geo   widget  geometri        extra    person    isinst    backend       column   storag  foreign     func     decim    migrat       node        token         oper    verbos    cursor       opt   languag      media   translat     inlin       auth     tupl   serial    month   permiss    properti        true       report        child   headlin      getattr     list    transact   categori
# freq#3    120831   75543.5  54570.5    45220.7   43430.7      39543.2   37325.1    34070.2     29804.7    28542.1    28535.5   25837.3    24247.5   24110.8  23456.6   22780.4      22048.2   22032.2   21924.1    21049.1      20442.4  20243.3  20018.7  19051.8   18709.1   18185.2    18137.6      17599.9      17079.7   16619.7   16450.4   16253.5   15792.7    15703.2    15447.8   15443.3    14820.5  14507.9  13721.6  13318.7   12733.1     12426.5       12375      12011.5      11735.9   11608.8      11336.6  11319.5     10908.2    10860.6
# topic#4   licens      fals  softwar      ninja      true         conn      lang    permiss    properti     driver       bool  fieldnam    languag    column      tab      preg         elli    obtain     apach        lab        notic  subject  charact   upload  warranti      role  technolog         team      segment      deal      mock    profil       row       temp   basepath      guid       2012    shall   newlin     conf    person       flash   distribut        unabl         free     impli        alter   articl       month   platform
# freq#4     37904   19863.4  18319.3    17318.9   16572.6      12683.8   11392.8    9604.97     8011.77    7985.91    7915.07   7616.94    7505.69   7368.66  6533.37   5339.97      5292.86   4957.05   4823.29    4817.29       4742.3  4588.13  4585.91  4373.31   4200.28   4027.05    3810.65      3806.12      3696.43   3639.45    3547.4   3537.38    3478.9    3421.36    3413.34   3407.41    3403.39  3368.16   3363.3  3318.85   3287.05     3034.74     3025.57      3005.57      2976.41   2854.66      2848.67  2818.19     2766.14    2609.53
# topic#5   deploy      node     oper     servic  descript  contributor   softwar       home      lesser     licens       list   foundat  subsystem      boss     java     fifth  redistribut    boston   publish       free      cluster   archiv   resolv      xml  properti      term     thread         pool        modul      role   registr  transact      hope  transform       1301    socket  distribut  factori    floor   receiv  warranti        step       child      persist          web    writer      marshal     bean  repositori         ha
# freq#5    375438    234408   211714     166681    150955       125773    111715    97776.6     96220.6    92202.6    85246.1   77829.2    65632.3   64363.6  64210.4   62203.2      58055.7   54591.5   53912.4    52705.3      51872.7  50433.6  49022.7  48635.3   48264.8     47026    43007.7      41544.7      41541.3   41102.1   40566.4   39479.1   38780.9    38375.4    37238.7   36203.3    35412.2  34868.2    34151  32820.5   32624.8     31591.4     31294.2        29848      27871.7   26766.7      26223.7  26120.9     25822.7    24890.4
# topic#6     cake      true   articl     licens      2007       plural  translat        php      plugin         md         aw     lower      upper      appl   letter  multibyt        capit      2006    fixtur       suit         2005   router  foundat  softwar       lib  descript     associ         fals      publish  properti    column  categori   everyth         ha  subpackag  dispatch         db     node     task     preg   project          id     primari         auth      languag     assoc        strpo    ident       shell      latin
# freq#6   52411.6   26433.3  20963.5    20025.8   19023.6      16844.4   16738.9    13454.5     11983.2    11565.4      10290   9970.37    9786.02    9399.8  8689.66   8528.47      8241.42   8222.04   8058.14    7658.84      7556.67  7241.24  7208.08  7188.28   7141.89    6946.6    6759.79       6699.6      6633.53   6578.77   6528.83   6382.97   6215.75    6096.65    5945.19   5937.32    5932.86  5424.05  5358.88  5149.13    4766.9     4577.97     4548.28      4542.44      4463.05   4422.25       4267.8  4085.75      4004.8    4002.19
# topic#7     mock      lotu     rack  middlewar      proc      respond      spec        opt       asset       halt      deleg     frame       sass     inlin     rubi      haml       router    mailer     coffe      adapt      pathnam     book    mutat    freez      gsub  minitest  dashboard       expand     overload      boom    scheme     upcas    fixtur       rdoc       slim      rest     lookup     verb    stage      var     simul      polici  repositori          gem      protect    enoent  architectur    yield       wrong   accessor
# freq#7   3864.58   3318.28  2766.27    1879.58   948.298      833.957   827.638    793.088     693.287    688.723    654.497    595.14    592.359   508.773  472.503   443.962      441.578    413.46   410.621    400.936      383.676  366.079  359.318  348.482    347.47    343.65    337.797      315.779      310.491   303.563   294.419   283.453   273.049    260.439    255.452   253.488    250.689  231.665  223.622  222.886     218.6      204.59     200.091      197.178      193.872   187.561      185.349  179.413     176.752    176.732
# topic#8      var    record     dict     plugin    isinst          row  tablenam       auth     languag     welcom      modul     adapt     scheme     flash   import    socket       thread    servic    expand       edit         rule   python     utf8     func      disk    router       task         span         node      cell    upload    ticket   sinatra      unabl     driver      soap     profil  illustr     pack   upgrad    licens  startswith    markdown       packet         menu  endpoint        frame   storag      button     margin
# freq#8   9744.98   9586.35  8288.89    7993.94    6897.4      5571.71   5504.96    5374.78      4932.6    4855.78    4632.98   4186.21    4168.03   3941.73  3832.52   3791.85      3690.75    3590.7   3550.54    3544.51      3445.57  3318.95  3302.77  3257.65   3168.43   3094.36    3084.92      3058.87      2841.73   2829.21   2826.13   2818.02   2791.04    2759.82    2620.01   2582.08    2567.59  2470.91  2418.51  2405.97   2394.91     2347.05     2251.03      2168.74       2133.2    2118.2      2096.75  2086.11     2084.56    2045.43
# topic#9   servic   softwar   licens       oper      free       lesser      java  distribut        list       node   warranti   factori       bean  properti    javax   foundat        modul  descript    deploy  subsystem  contributor  servlet    impli   receiv       fit       xml   merchant        annot  interceptor     floor  transact      1301      boss       hope     archiv   persist       term      web    junit     home   publish      boston     cluster  redistribut        fifth     timer       listen       id      writer  connector
# freq#9    569086    516347   450676     355835    322696       280580    247214     243619      234088     226092     224102    208350     207094    182545   177260    172602       158391    158253    145584     143569       132443   120640   116522   112690    105775    102763     101746       100541      97161.4   91919.1   91594.4   88504.7   88489.6    87165.9      86392     81580    79552.3  75628.5  74647.5  73434.7   72765.6     71201.7     70147.5      68324.3      63596.7   60955.5      58661.8  55994.1       55296      49096

# %% [markdown]
# # 2- Project-topic

# %%
projects_topics = lda.transform(tf)
projects_topics.shape
# Out:
# (226, 10)

# %%
df = pd.DataFrame(projects_topics, columns=['topic'+str(i) for i in range(10)])
df['project'] = project_names
df['project'] = df['project'].apply(lambda x: x.split('_')[0].split('-')[0])
df['date'] = project_names
df['date'] = df['date'].apply(lambda x: x.split('_')[1])
df.index = project_names
df.to_csv('project-topic_7_1.csv')
df.head()
# Out:
#                              topic0     topic1       topic2    topic3      topic4    topic5        topic6    topic7    topic8    topic9  project     date
# cakephp-tags_2014-06  110276.370135   0.100024     0.100023  0.100022    0.100025  0.100025  41995.829680  0.100018  0.100024  0.100023  cakephp  2014-06
# cakephp-tags_2012-01   72752.157767   0.100022     0.100037  0.100020    0.100022  0.100022  58371.042053  0.100017  0.100021  0.100020  cakephp  2012-01
# cakephp-tags_2006-06    6427.725487  48.395820     0.100024  0.100026  246.901196  0.100027  12059.377344  0.100016  0.100029  0.100030  cakephp  2006-06
# cakephp-tags_2016-01  123996.816797   0.100029  1010.382988  0.100027    0.100027  0.100029      0.100022  0.100026  0.100027  0.100027  cakephp  2016-01
# cakephp-tags_2013-06  102283.891549   0.100024     0.100023  0.100021    0.100024  0.100025  43675.308271  0.100019  0.100022  0.100022  cakephp  2013-06

# %%
print()

# %%
# proj_df = df.groupby('project')
# for i, g in proj_df:
#     g[df.columns[0:7]].plot(kind='bar')
